# %%
import matplotlib.pyplot as plt

numeric_data = housing_data.select_dtypes(include=[np.number])


plt.figure(figsize=(10, 6))
plt.scatter(housing_data['median_income'], housing_data['median_house_value'], alpha=0.5)
plt.title('Mediana dochodów vs. Mediana wartości nieruchomości')
plt.xlabel('Mediana dochodów')
plt.ylabel(' Mediana wartości nieruchomości')
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 8))
corr_matrix = numeric_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Mapa cieplna korelacji między zmiennymi')
plt.show()


plt.figure(figsize=(10, 6))
plt.hist(housing_data['median_house_value'], bins=50, color='skyblue', edgecolor='black')
plt.title('Rozkład mediany wartości nieruchomości')
plt.xlabel('Mediana wartości nieruchomości')
plt.ylabel('Liczba wystąpień')
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
mean_house_values = housing_data.groupby('ocean_proximity')['median_house_value'].mean().sort_values()
mean_house_values.plot(kind='bar', color='coral')
plt.title('Średnia wartość nieruchomości w zależności od bliskości oceanu')
plt.xlabel('Bliskość oceanu')
plt.ylabel('Średnia wartość nieruchomości')
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.scatter(housing_data['longitude'], housing_data['latitude'], c=housing_data['median_house_value'], cmap='viridis', alpha=0.5)
plt.colorbar(label='Mediana wartości nieruchomości')
plt.title('Wartość nieruchomości w zależności od lokalizacji')
plt.xlabel('Długość goegraficzna')
plt.ylabel('Szerokość geograficzna')
plt.grid(True)
plt.show()

# Wykres rozrzutu
# Ten wykres rozrzutu pokazuje zależność między medianą dochodów a medianą wartości nieruchomości.

# Wnioski
# Korelacja pozytywna: Wyższe dochody są zazwyczaj związane z wyższymi wartościami nieruchomości.
# Zróżnicowanie wartości: Widać, że przy wyższych dochodach wartość nieruchomości może się różnić, ale ogólnie rośnie.

# 2. Mapa cieplna korelacji między zmiennymi
# Mapa cieplna przedstawia macierz korelacji między wszystkimi zmiennymi w zbiorze danych. Korelacje mierzą, jak silnie dwie zmienne są ze sobą powiązane.

# Silne korelacje: Na przykład, możemy zauważyć silną korelację między median_income a median_house_value.
# Słabe lub brak korelacji: Niektóre zmienne mogą nie mieć istotnej korelacji, co można zidentyfikować przez kolory zbliżone do neutralnego.

# 3. Histogram rozkładu median_house_value
# Histogram pokazuje rozkład mediany wartości nieruchomości (median_house_value).

# Wnioski
# Rozkład danych: Możemy zobaczyć, jak często występują różne wartości nieruchomości w zbiorze danych.
# Dominujące wartości: Można zidentyfikować dominujące wartości, np. skupienie się danych w określonym przedziale cenowym.

# 4. Wykres słupkowy średnich wartości dla różnych kategorii ocean_proximity
# Wykres słupkowy przedstawia średnią wartość nieruchomości dla różnych kategorii bliskości do oceanu (ocean_proximity).

# Wnioski
# Wpływ lokalizacji: Lokalizacja blisko oceanu lub zatoki (NEAR OCEAN, NEAR BAY) ma wyższe średnie wartości nieruchomości w porównaniu do nieruchomości w głębi lądu (INLAND).
# Atrakcyjność lokalizacji: Bliskość do wody wpływa pozytywnie na wartość nieruchomości.

# 5. Mapa punktowa wartości nieruchomości na mapie w zależności od lokalizacji
# Mapa punktowa przedstawia wartości nieruchomości na mapie geograficznej w zależności od ich lokalizacji (longitude i latitude).

# Wnioski
# Rozkład geograficzny: Możemy zobaczyć, jak wartości nieruchomości są rozmieszczone geograficznie.
# Lokalne hotspoty: Obszary o wysokich wartościach nieruchomości mogą być zidentyfikowane na mapie.
